# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from threading import Condition
import os

# %%
cv = Condition()
with cv:
    while not os.path.exists("test.txt"):
        cv.wait(timeout=2)
# Out:
# Moving on

# %%
# %matplotlib inline
x = np.arange(0,24*np.pi,np.pi/4)
y = np.sin(x)
for i in range(int(len(y)/10)):
    plt.figure()
    plt.plot(y)
    plt.xlim((i,i+20))
    plt.savefig("stuff{}".format(i))
